# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# map(function_to_apply, list_of_inputs)
t = np.arange(0,2.5,0.1)
y1 = map(math.sin,math.pi*t)
y2 = map(math.sin,math.pi*t+math.pi/2)
y3 = map(math.sin,math.pi*t-math.pi/2)
y1 = list(y1)
y2 = list(y2)
y3 = list(y3)
plt.plot(t,y1,'b*',t,y2,'g^',t,y3,'ys')
# Out:
# [<matplotlib.lines.Line2D at 0x112657278>,
#  <matplotlib.lines.Line2D at 0x112657400>,
#  <matplotlib.lines.Line2D at 0x112657c50>]

# %%
plt.plot(t,y1,'g',t,y2,'b',t,y3,'purple')
# Out:
# [<matplotlib.lines.Line2D at 0x112b16198>,
#  <matplotlib.lines.Line2D at 0x112b16358>,
#  <matplotlib.lines.Line2D at 0x112b16c18>]

# %%
#x1 = []
#x2 = []
#x3 = []
#for a, b, c in zip(y1, y2, y3):
#    x1.append(a)
#    x2.append(b)
#    x3.append(c)
# plt.plot(t,x1,'b',t,x2,'g',t,x3,'y')
